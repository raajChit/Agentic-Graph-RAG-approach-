# %%
import os

# %%
def process_pdf_with_processor(
    project_id: str,
    location: str,
    processor_id: str,
    file_path: str
):
    
    from google.api_core.client_options import ClientOptions
    from google.cloud import documentai
    """
    Uses an existing processor to parse a PDF file via Document AI.
    """
    opts = ClientOptions(api_endpoint=f"{location}-documentai.googleapis.com")
    client = documentai.DocumentProcessorServiceClient(client_options=opts)

    # Build the processor resource name
    processor_name = f"projects/{project_id}/locations/{location}/processors/{processor_id}"
    # Read the PDF into memory
    with open(file_path, "rb") as image:
        image_content = image.read()

    # Prepare the raw document
    raw_document = documentai.RawDocument(
        content=image_content, mime_type="application/pdf"
    )

    # Construct the request
    request = documentai.ProcessRequest(
        name=processor_name,
        raw_document=raw_document,
    )

    # Send the request
    result = client.process_document(request=request)
    document_object = result.document

    print("DOCUMENT TEXT PARSED")
    print("\n\nSENDING FOR TRANSLATION")
    return document_object.text

# %%
def chunking_text(full_text: str, chunk_size: int = 1000, overlap: int = 200):
  
  
    chunks = []
    start = 0
    end = chunk_size

    chunk_index = 0
    while start < len(full_text):
        # Extract the chunk
        text_chunk = full_text[start:end]
        
        # Construct metadata. You can add page numbers if you have them.
        metadata = {
            "chunk_index": chunk_index
        }
        
        chunks.append({
            "text": text_chunk,
            "metadata": metadata
        })
        
        # Move the window
        start = end - overlap
        end = start + chunk_size
        chunk_index += 1

    return chunks

# %%
def translate_text(target_language: str, text: str, folder: str = "processed_files", filename: str = "translated_doc.txt") -> dict:
    """Translates text into the target language.

    Target must be an ISO 639-1 language code.
    See https://g.co/cloud/translate/v2/translate-reference#supported_languages
    """
    from google.cloud import translate_v2

    translate_client = translate_v2.Client()

    if isinstance(text, bytes):
        text = text.decode("utf-8")

    detection = translate_client.detect_language(text)
    source_lang = detection["language"]

    if source_lang != target_language:
        translation = translate_client.translate(
            text, target_language=target_language
        )
        result =  translation["translatedText"]

    else:
        result = text
        

    os.makedirs(folder, exist_ok=True)

    file_path = os.path.join(folder, filename)

    with open(file_path, "w", encoding="utf-8") as file:
        file.write(result)
   

    print(f"Translation saved to {file_path}")
    print(f"Detected source language: {source_lang}")

# %%
import config
def parse_and_translate_pdf(target_language, file_location):
    parsed_text = process_pdf_with_processor(
        config.PROJECT_ID,
        config.LOCATION,
        config.PROCESSOR_ID,
        file_location
    )
    translate_text(target_language, parsed_text)

# %%
file_path = "sample.pdf"
parse_and_translate_pdf('en', file_path)
# Out:
# DOCUMENT TEXT PARSED
#
#
# SENDING FOR TRANSLATION
# Translation saved to processed_files/translated_doc.txt
# Detected source language: mr

# %%
import config


def parse_and_translate_pdf(target_language, file_location):
  
    # Parsing PDF text
    parsed_text = process_pdf_with_processor(
        config.PROJECT_ID,
        config.LOCATION,
        config.PROCESSOR_ID,
        file_location
    )

    # Chunkin the text into smaller pieces
    chunks = chunking_text(parsed_text)

    # translating each chunk
    translated_chunks = []
    for chunk_data in chunks:
        chunk_text = chunk_data["text"]
        metadata = chunk_data["metadata"]
    
        result = translate_text(target_language, chunk_text)
        translated_chunk = {
            "translated_text": result["translatedText"],
            "detected_source_language": result["detectedSourceLanguage"],
            # Include metadata so we keep track of position, page, etc.
            "metadata": metadata
        }
        translated_chunks.append(translated_chunk)

    return translated_chunks

# %%
import openai
from langchain_openai import OpenAIEmbeddings
from langchain_pinecone import PineconeVectorStore
from langchain.document_loaders import DirectoryLoader, TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
# Replace with your real OpenAI API key

def get_openai_embedding(text: str, file_path: str) -> list:
    embeddings = OpenAIEmbeddings(model="text-embedding-ada-002")
    loader = DirectoryLoader(file_path, glob="*.txt", loader_cls=TextLoader)  # Load only .txt files
    documents = loader.load()

    # Use a TextSplitter to split the documents into chunks
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=2000, chunk_overlap=50)
    split_documents = text_splitter.split_documents(documents)
    response = openai.Embedding.create(
        model="text-embedding-ada-002",
        input=text
    )
    embedding_vector = response["data"][0]["embedding"]  # a list[float]
    return embedding_vector

# %%
import os
from langchain_pinecone import PineconeVectorStore
from langchain_openai import OpenAIEmbeddings
from langchain.document_loaders import DirectoryLoader, TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
import openai

# Set your API keys for OpenAI

# Initialize OpenAI Embeddings using LangChain
embeddings = OpenAIEmbeddings(model="text-embedding-ada-002")  # Specify which embedding model

# Load all text files from a directory
directory_path = "./processed_files"  # directory path with all the national weather service documents
loader = DirectoryLoader(directory_path, glob="*.txt", loader_cls=TextLoader)  # Load only .txt files
documents = loader.load()

# Use a TextSplitter to split the documents into chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=2000, chunk_overlap=50)
split_documents = text_splitter.split_documents(documents)

# Connect to the Pinecone index using LangChain's Pinecone wrapper
# Add all the split documents into the Pinecone vector database
pinecone_index_name = "real-estate-docs"
vectorstore = PineconeVectorStore(index_name=pinecone_index_name, embedding=embeddings)
vectorstore.add_documents(documents=split_documents )

print("Embeddings from text files residing in the directory, created, and inserted in Pinecone Vector Database successfully!")
# Out:
# Embeddings from text files residing in the directory, created, and inserted in Pinecone Vector Database successfully!

# %%
vectorstore = PineconeVectorStore(index_name=pinecone_index_name, embedding=embeddings)

# %%
vectorstore.delete(delete_all=True)

# %%
def embed_and_index_chunks(
    chunks: list,
    index,   # pinecone.Index object
    document_id: str,
    references: list = None
):

    vectors_to_upsert = []

    # Example of how you might represent relationships across docs
    # in metadata if you have them
    doc_relationships = references or []  # e.g. ["magma-circular-2023", "DCPR-guidelines-v2"]

    for chunk in chunks:
        text = chunk["translated_text"]
        chunk_meta = chunk["metadata"]

        # Create a unique ID for the chunk in this doc
        chunk_index = chunk_meta.get("chunk_index", 0)
        vector_id = f"{document_id}-chunk{chunk_index}"

        # Embed the chunk with OpenAI
        embedding_vector = get_openai_embedding(text)

        # Add any extra metadata you want:
        #  - the text content (if you want to keep it in Pinecone)
        #  - the doc ID
        #  - cross-reference doc relationships
        pinecone_metadata = {
            "chunk_index": chunk_index,
            "document_id": document_id,
            "relationships": doc_relationships, 
            "text": text,  # you can store the chunk text, or a summary
        }

        vectors_to_upsert.append({
            "id": vector_id,
            "values": embedding_vector,
            "metadata": pinecone_metadata
        })

    # Upsert all chunks in a single call
    index.upsert(vectors=vectors_to_upsert, namespace="circulars")
    print(f"Upserted {len(vectors_to_upsert)} chunks from '{document_id}' to Pinecone.")

# %%
index = pinecone_init()
file_path = "sample.pdf"

chunks = parse_and_translate_pdf('en',file_path)
embed_and_index_chunks(chunks, index, document_id="circulars")
# Out:
# ##################file path is sample.pdf
# DOCUMENT TEXT PARSED
#
#
# SENDING FOR TRANSLATION
# Translation: Subject: Brihanmumbai Municipal Corporation Garden Department Circular No.0041/33/2013- JTMC-DMU dated 17/06/13 Trees NoC Cantalo Under Section 8 of the Maharashtra (Urban Areas) Tree Preservation Act, 1975, permission is also given for cutting and replanting of trees coming under various development works. For this, applications are received from various public infrastructure development organizations, as well as private building, professionals, architects. The application for infrastructure from various development organizations is circulated to the Tree Authority officers. In addition, the proposal for cutting of trees coming under development on private land is received from the concerned developer. Before submitting the proposal to the Garden Department, the Building Proposal Department gives permission for the development work against the No Objection Certificate of the Tree Authority. It has been observed that there is delay in this process and due to this development works are getting stuck. Tree Authority dated 5.3.2013
# Detected source language: mr
# Translation: The work is permitted against the No Objection Certificate of the Tree Authority. It has been observed that this procedure causes delay and due to this, development works are stuck. In the meeting of the Tree Authority dated 5.3.2013, it was ordered that the said procedure should be prepared in a loose and implementable manner. After exchanging views on this, the following is proposed. 1. Procedure No. DySG/TA/MC/568 dated 7.10.2006 and Tree Authority&#39;s subject No. 176 Tree Authority dated 7.10.2006 along with resolution No. M.C./6785/ Vrupra dated 7.11.2006 has been passed. 2. Applications received under this Act are received from architects, owners of the site etc. It is found that there is a strong demand for cutting down trees and sometimes for replanting them, but when analyzing the reasons why these trees do not survive, it is found that the replanting is not done in a scientific manner. For this, the concerned developers should consult a qualified plant scientist.
# Detected source language: mr
# Translation: There is an urge to replant trees but while analyzing the reasons why these trees are not surviving, it has been found that the replanting is not done in a scientific manner. For this, the concerned developers have not taken the help of a qualified horticulturalist. Henceforth, all such applications will have to be made through such horticulturalist as per Appendix-1, tree-wise as per Appendix-1. 3. In the case of proposals for cutting/replanting trees under various projects of the Municipal Corporation, the concerned Account Head will prepare a proposal using the above procedure and submit it to the Tree Authority Officer J-17105(1-4) 38 2013. The Tree Authority Officer will submit it to the Tree Authority with his/her feedback within the next 45 working days. 4. In the case of proposals for cutting/replanting trees through government and semi-government institutions, the concerned government institution will prepare a proposal using the above procedure and submit it to the Tree Authority Officer. The Tree Authority Officer will submit it to the Tree Authority with his/her feedback within the next 45 working days. 5. Private developers
# Detected source language: mr
# Translation: The proposal will be prepared using the information provided in the Annexure-I and submitted to the Tree Authority Officer. The Tree Authority Officer will submit his/her opinion to the Tree Authority within 45 working days. 5. Proposals from private developers a) If there is no tree on the plot on which development work is to be done and there is no objection to the proposal being passed by the concerned officers of the Building Proposal Department after taking note of the same. Therefore, such proposals should not be sent to the Tree Authority Officer/Park Superintendent for a No Objection Certificate. b) The registered botanical garden scientist will prepare the information of the trees on the plot on which development work is to be done and there are trees on the same plot but these trees do not obstruct the proposed development work and submit it to the concerned Building Proposal Department as per Appendix &#39;A&#39;. The officers will certify accordingly and thereafter such proposals will be sent to the Park Superintendent for information. If the Park Superintendent finds any error in the proposal for planting trees, the building proposal will be approved within 7 days of receipt of the proposal.
# Detected source language: mr
# Translation: After the verification of the same, such proposals will be sent to the Superintendent of Gardens for information. If any errors are found in the proposal for planting trees, the Superintendent of Gardens will bring them to the notice of the Building Proposal Officer within 7 days of receipt of the proposal. a) It has been observed in many previous proposals regarding the trees that are obstructing the development work on the plot on which development work is to be done that many times there are proposals to cut down large numbers of trees for constructing parking lots, multi-level podiums, for the movement of vehicles and for fire engines. In this city as well as in such new buildings, the need for trees is more than the need for cars. Every architect should show the existing trees in the map accompanying the application for no objection permit of Mumbai Fire Department and Transport Department, and the recommendation for the need for cutting such trees should be included in the no objection permit issued by the concerned department. If the tree cutting is proposed excluding the needs of Mumbai Fire Department and parking needs, in such a situation, the concerned developer should not
# Detected source language: mr
# Translation:  The recommendation should be included in the no objection permit issued by the concerned department. If tree felling is proposed except for the needs of Mumbai Fire Department and parking needs, in such a situation, the concerned developer should see how the building can be designed without cutting the trees and if even then it is felt that cutting the trees is necessary, the following procedure should be followed. The concerned developer/architect should first submit the construction proposal to the Building Proposal Department 3-17105(2) and submit a detailed plan of which and how many trees need to be cut tree-wise through the Botanical Garden Specialist as per Appendix A. In addition, the following two reasons should be given regarding why the relevant trees need to be cut: (1) Detailed reasons for cutting each tree-wise should be given. (2) If the tree is not to be cut, what kind of tree-wise exemption is required should be given. After receiving the proposal as above, the concerned officer of the Building Proposal Department, the circle-wise officer of the Garden Department and the concerned architect will hold a meeting and the concerned developer will submit the detailed plan to the Architect.
# Detected source language: mr
# Translation: After receiving the proposal, the concerned officer of the Building Proposal Department, the circle-wise officers of the Parks Department and the concerned architect will hold a meeting and ask the concerned developer architect to modify the proposal in a suitable manner so that it will not be necessary to cut down the trees and if this is not possible, they will decide which exemptions are required to be given through the Commissioner to save the trees and send the proposal to the Commissioner and in cases where it is not possible to give exemptions as per the rules and change the map to save the trees, the proposal for such trees will be submitted to the concerned Zonal Deputy Parks Superintendent mentioning all the above points. After completing all the procedures mentioned in point no. 1 from the date of receipt of the proposal, it will be submitted to the Tree Authority within 45 days. 6) In some cases other than development work, it is necessary to remove or prune trees, the work on which will be as follows: a. Dead tree removal: If dead trees are found on roads, parks, grounds, other public open spaces, municipal land and due to this,
# Detected source language: mr
# Translation: The work on which it is necessary to remove or prune trees will be as follows: a. Dead trees: If dead trees are found on roads, parks, grounds, other public open spaces, municipal areas and if this creates an obstacle for traffic and other purposes, the Assistant Superintendents will inspect and give an opinion regarding the deadness of these trees and then such trees will be removed by the officers of the Parks Department in the department office. While removing them, it should be ensured that this will be done at the root. In places other than the above-mentioned places, the concerned authority or private person will apply to the Parks Department of the concerned department and after this, the Assistant Parks Superintendent will inspect and give an opinion that the said tree is dead and after this, the concerned authority or private person can remove such trees. However, it will be essential to take clear photographs of such trees before, during and after such removal. The said photographs will be submitted to the Parks Department of the department within 7 days for storage.
# Detected source language: mr
# Translation: It will be necessary to take clear photographs of such trees during and after pruning. The concerned authority or private person will submit these photographs to the Department of Parks within 7 days for storage. Dangerous trees ..Y.. J-17 105 (3) If dangerous trees are found on roads, parks, grounds, other public open spaces, municipal areas and if this causes obstruction to traffic and other uses, the Assistant Parks Superintendent will inspect them and give his opinion about it and will clearly state how to prune such trees. Also, after pruning, the broken parts of the tree will be covered with suitable coating. In other places, the concerned authority or private person will apply to the Parks Department and after this, the Assistant Parks Superintendent will inspect the tree and give his opinion that the said tree is a dangerous tree and after this the concerned authority or private person can eradicate such tree. However, before, during and after such eradication, it will be necessary to take clear photographs of such tree. The said photograph
# Detected source language: mr
# Translation: The concerned authority or private entity may remove such trees. However, it will be essential to take clear photographs of such trees before, during and after such removal. The concerned authority or private entity shall submit the said photographs to the Parks Department of the Department within 7 days for storage. A. Tree Pruning In order to prevent trees from becoming dangerous, falling on roads, parks, grounds, other public open spaces, municipal areas and to increase the life span, balance and growth of such trees, it is necessary to prune the trees in various ways. The officers of the Parks Department of the Department in the Department office will inspect them from time to time and prune them as required and apply appropriate coating on the pruned areas. In other places, the concerned authority or private entity shall apply to the Parks Department of the concerned department and after this, the concerned officer shall inspect the site and give his opinion on pruning the said tree within the next 7 days and after this, the concerned authority or private entity shall prune such trees.
# Detected source language: mr
# Translation: The application will be made to the Parks Department and after this, the concerned officer will inspect the site and give his opinion on the pruning of the said tree within the next 7 days and after this, the concerned authority or private person will be able to remove such tree. It will be necessary to take clear photographs of such trees before and after such pruning. The concerned authority or private person will submit these photographs to the Parks Department of the Department within 7 days for archiving. N. Baharodhak Kukad Kukandar Toll 86), somn Parks Superintendent Chief Engineer Joint Commissioner (Avya) Additional Commissioner (P.U) ܦ Copy- (Development Planning) Parks Superintendent and Tree Officer and all concerned officers of the Parks Department, all Assistant Commissioners (Ate T Department) 3) All Municipal Deputy Commissioners (Circ. 1 to 7) Chief Engineer (Blood and Transport) Bundis 17/2 Hon. Commissioner 1 Chief Engineer (Development and Planning): A copy of this circular should be distributed to all the concerned officers of your department. 1) Director (Information Technology): This circular may be uploaded on the website of M.N.P. Office Operations.
# Detected source language: mr
# Translation: Planning): A copy of this circular should be distributed to all the concerned officers of your department. 1) Director (Information Technology): This circular should be uploaded on the website of M.N.P. Office System. (5) 1
#
# Detected source language: mr
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[45], line 5
#       2 file_path = "sample.pdf"
#       4 chunks = parse_and_translate_pdf('en',file_path)
# ----> 5 embed_and_index_chunks(chunks, index, document_id="circulars")
#
# Cell In[44], line 23, in embed_and_index_chunks(chunks, index, document_id, references)
#      20 vector_id = f"{document_id}-chunk{chunk_index}"
#      22 # Embed the chunk with OpenAI
# ---> 23 embedding_vector = get_openai_embedding(text)
#      25 # Add any extra metadata you want:
#      26 #  - the text content (if you want to keep it in Pinecone)
#      27 #  - the doc ID
#      28 #  - cross-reference doc relationships
#      29 pinecone_metadata = {
#      30     "chunk_index": chunk_index,
#      31     "document_id": document_id,
#      32     "relationships": doc_relationships,
#      33     "text": text,  # you can store the chunk text, or a summary
#      34 }
#
# Cell In[41], line 10, in get_openai_embedding(text)
#       6 def get_openai_embedding(text: str) -> list:
#       7     """
#       8     Gets the embedding for `text` using OpenAI's text-embedding-ada-002.
#       9     """
# ---> 10     response = openai.Embedding.create(
#      11         model="text-embedding-ada-002",
#      12         input=text
#      13     )
#      14     embedding_vector = response["data"][0]["embedding"]  # a list[float]
#      15     return embedding_vector
#
# File ~/Desktop/Multi--Agent-PDF-Intelligence-System/env/lib/python3.13/site-packages/openai/lib/_old_api.py:39, in APIRemovedInV1Proxy.__call__(self, *_args, **_kwargs)
#      38 def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# You tried to access openai.Embedding, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
